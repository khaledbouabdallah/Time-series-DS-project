# %% [markdown]
# # REPRODUCE BEST MODEL FOR PART A
#
# ### NOTE: Running this using CPU instead of GPU will give different results since initialization  is different.
#
# ### TO GET THE EXACT RESULTS AS WE DID RUN THIS WITH A CUDA SUPPORTED GPU!

# %%
import pandas as pd 
from xgboost import XGBRegressor
from skforecast.ForecasterAutoreg import ForecasterAutoreg
import matplotlib.pyplot as plt

# %%
# Load and prepare data
path = "data/ETTh1.csv"
df = pd.read_csv(path)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df.drop("Id", axis=1, inplace=True)
df = df.asfreq('H')
df = df.sort_index()
df.head()
# Out:
#                             OT
# date
# 2016-07-01 00:00:00  30.531000
# 2016-07-01 01:00:00  27.787001
# 2016-07-01 02:00:00  27.787001
# 2016-07-01 03:00:00  25.044001
# 2016-07-01 04:00:00  21.948000

# %%
results_search = pd.read_csv("data/results_val.csv")
results_search.head(15)
# Out:
#     Unnamed: 0  lags                                             params  \
# 0           42  2880  {'n_estimators': 800, 'max_depth': 6, 'learnin...
# 1           46  2880  {'n_estimators': 800, 'max_depth': 6, 'learnin...
# 2           15  2880  {'n_estimators': 900, 'max_depth': 6, 'learnin...
# 3           49  2880  {'n_estimators': 800, 'max_depth': 6, 'learnin...
# 4           28  2880  {'n_estimators': 1000, 'max_depth': 6, 'learni...
# 5           43  2880  {'n_estimators': 1000, 'max_depth': 6, 'learni...
# 6            5  2880  {'n_estimators': 1000, 'max_depth': 6, 'learni...
# 7           45  2880  {'n_estimators': 900, 'max_depth': 7, 'learnin...
# 8           34  2880  {'n_estimators': 1100, 'max_depth': 5, 'learni...
# 9           13  2880  {'n_estimators': 800, 'max_depth': 6, 'learnin...
# 10          36  2880  {'n_estimators': 1100, 'max_depth': 5, 'learni...
# 11          12  2880  {'n_estimators': 800, 'max_depth': 5, 'learnin...
# 12          41  2880  {'n_estimators': 900, 'max_depth': 6, 'learnin...
# 13          47  2880  {'n_estimators': 800, 'max_depth': 6, 'learnin...
# 14          32  2880  {'n_estimators': 900, 'max_depth': 6, 'learnin...
#
#     mean_absolute_error  n_estimators  max_depth  learning_rate  reg_alpha  \
# 0              2.125747         800.0        6.0       0.063657        0.3
# 1              2.191437         800.0        6.0       0.062355        0.2
# 2              2.232195         900.0        6.0       0.013309        0.3
# 3              2.271540         800.0        6.0       0.038502        0.5
# 4              2.294565        1000.0        6.0       0.090127        0.6
# 5              2.310258        1000.0        6.0       0.062798        0.3
# 6              2.346478        1000.0        6.0       0.121849        0.3
# 7              2.358618         900.0        7.0       0.127467        0.1
# 8              2.375260        1100.0        5.0       0.010066        0.3
# 9              2.410578         800.0        6.0       0.018067        0.9
# 10             2.411749        1100.0        5.0       0.046179        0.1
# 11             2.415369         800.0        5.0       0.021575        0.8
# 12             2.426376         900.0        6.0       0.013670        0.2
# 13             2.468969         800.0        6.0       0.088620        0.0
# 14             2.479128         900.0        6.0       0.046006        0.7
#
#     reg_lambda
# 0          1.0
# 1          0.8
# 2          0.8
# 3          0.9
# 4          0.8
# 5          0.8
# 6          0.6
# 7          0.6
# 8          0.9
# 9          1.0
# 10         0.7
# 11         1.0
# 12         0.9
# 13         0.8
# 14         1.0

# %% [markdown]
# ## Best model
#
# Our best model is the model in the __10'th__ row which corespondes to our "submission_10" submission and its predictios are located in the column __prediction_10__ in __predictions_all.csv__
#
# __note__: somehow running the XGBOOST on cpu will change the model predictions and thus will result in different mea, to get the exact result that I had and submitted you have to run in on a cuda device (gpu).

# %%
row = results_search.iloc[10]
print(f" index: {row['Unnamed: 0']} params: ", row["params"])
# Out:
#  index: 36 params:  {'n_estimators': 1100, 'max_depth': 5, 'learning_rate': 0.04617887276102834, 'reg_alpha': 0.1, 'reg_lambda': 0.7000000000000001}

# %%
forecaster = ForecasterAutoreg(
             regressor = XGBRegressor(random_state=123,
                                      tree_method='hist',
                                      device='cuda', learning_rate= row["learning_rate"],
                                      max_depth	= int(row["max_depth"]), n_estimators = int(row["n_estimators"]),
                                      reg_alpha= row["reg_alpha"], 	reg_lambda = row["reg_lambda"]),
             lags            = int(row["lags"])  )

forecaster.fit(df["OT"])
predictions = forecaster.predict(100)
# Out:
# c:\Users\bouab\Documents\DCI_S2\Data_Science\Time-series-DS-project\.venv\lib\site-packages\xgboost\core.py:160: UserWarning: [18:34:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\context.cc:44: No visible GPU is found, setting device to CPU.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ## Visualizng best model forecast

# %%
plt.figure(figsize=(20, 10))
plt.plot(df["OT"], label='Original Data')
plt.plot(predictions, label='Model forecast')
plt.xlabel('Date')
plt.ylabel('OT')
plt.title('Forecast plot')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(df.iloc[-300:]["OT"], label='Original Data')
plt.plot(predictions, label='Model forecast')
plt.xlabel('Date')
plt.ylabel('OT')
plt.title('Forecast plot')
plt.legend()
plt.show()
